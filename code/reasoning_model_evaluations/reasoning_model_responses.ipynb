# %% [markdown]
# ## Does a reasoning model provide better solutions to the MacGyver problems?
#
# The MacGyver problems are a set of problems that are used to compare the ability to think out of the box to solve commonplace problems that are grounded in the physical world. Not all problems can be solved, and those that can be solved are not always solved by the LLM. This test and paper was done in March 2024 and the best model at that time (which also showed the best overall performance) was GPT-4.
#
# Given the latest excitement and hype around reasoning models, we thought it would be interesting to see if a reasoning model can provide better solutions to the MacGyver problems.
#
# In the following notebook, we will be doing the following steps:
#
# 1. Read in the Excel file with problem statements
# 2. Send the problem statements to a reasoning model with the default prompt style used in the paper
# 3. Get the responses from the reasoning model
# 4. Potentially compare the responses with the ground truth solutions

# %% [markdown]
# ### Step 1: Read in the Excel file with problem statements

# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# Requirement already satisfied: pandas in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: openpyxl in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('../../data/MacGyver/problem_solution_pair.xlsx')

# Display the first 5 rows
display(df.head())
# Out:
#     ID                                            Problem Solvable?  \
# 0  541  You spilled red wine on the hotel carpet and w...       Yes
# 1  542  You accidentally locked your only pair of glas...       Yes
# 2  543  You have an important meeting but your suit is...       Yes
# 3  544  The hotel bathroom door handle is broken and y...       Yes
# 4  545  The hotel's WiFi signal is weak and you have a...       Yes
#
#   Unconventional?                                           Solution  \
# 0  unconventional  Step1: Open the bottle of mineral water with t...
# 1    conventional  Step1: Use the remaining battery in your smart...
# 2  unconventional  Step1: Hang the suit on the coat hanger on the...
# 3  unconventional  Step 1: Unbend the wire hanger and flatten it ...
# 4    conventional  Step1: Using the clothes hanger, create a hook...
#
#          Label  IsInteresting
# 0  inefficient            1.0
# 1   infeasible            NaN
# 2  inefficient            NaN
# 3  inefficient            0.0
# 4   infeasible            NaN

# %%
# Sample 10 random requests
sampled_df = df.sample(n=10, random_state=42)  # Setting random_state for reproducibility

# Display the sampled problems
display(sampled_df)
# Out:
#         ID                                            Problem Solvable?  \
# 1394  1322  You are on a road trip and the car breaks down...        No
# 743    911  A baseball has been thrown over a towering fen...       Yes
# 1606  1549  Your water purification tablets fell into a de...        No
# 49     358  Your puppy chewed up a pillow, and now there a...       Yes
# 188    384   You have to hang a wall decoration, but you c...       Yes
# 482    885  You want to make a sun dial to judge time, but...       Yes
# 892   1860  You are exploring through a zoo, and there's a...       Yes
# 613   1372  During a beach cleanup, you come across a heav...       Yes
# 1628  1640  A crack has formed on your car's radiator and ...        No
# 1347   791  You need to inflate a flat pool float but have...        No
#
#      Unconventional?                                           Solution  \
# 1394             NaN  It is not possible to fix a car engine with ju...
# 743     conventional  Step1: Tie the two jump ropes together to leng...
# 1606             NaN  Step1: Use the pot to collect rainwater or sta...
# 49    unconventional  Step1: Use the broken broom to gather the feat...
# 188   unconventional  Step1: Align the deck of cards along the wall ...
# 482   unconventional  Step1: Use the hand mirror as the sundial base...
# 892   unconventional  Step1: Fill the metallic bucket with fresh veg...
# 613   unconventional  Step1: Use the volleyball as a roller under th...
# 1628             NaN  Step1: Clean the cracked area on the radiator ...
# 1347             NaN  Step1: Take the trash bag and secure it around...
#
#                      Label
# 1394  correct_right_reason
# 743             infeasible
# 1606        wrong_solution
# 49             inefficient
# 188            inefficient
# 482             infeasible
# 892             infeasible
# 613              efficient
# 1628        wrong_solution
# 1347        wrong_solution

# %% [markdown]
# ## Step 2: Call the OpenAI API with a sample of the problems
#
# 1. Call the GPT-4o model to check how it responds and to make sure that call is happening
# 2. Call the o1 model to check how it responds and to make sure that call is happening

# %%
# !pip install openai
# !pip install python-dotenv
# Out:
# Requirement already satisfied: openai in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (1.61.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: python-dotenv in /Users/ramachandran/Documents/Self/Code/MacGyver/macgyver/lib/python3.12/site-packages (1.0.1)

# %%
import os
from dotenv import load_dotenv
load_dotenv('../../.env.dev')
# Out:
# True

# %%
import os
from openai import OpenAI
import time

# Initialize the OpenAI client
client = OpenAI()  # Make sure OPENAI_API_KEY is set in your environment variables
systemPrompt = "Give a valid (feasible and efficient) solution very concisely. Use step1, step2, etc, and mention the tools to achieve each step. Use as few steps as possible and the answer should ideally be less than 100 words. When there is not a feasible solution given the constraint and provided tools, just say that it is not possible and give a very short justification."

def get_completion(prompt):
    try:
        response = client.chat.completions.create(
            model="gpt-4o",  # Using GPT-4o (cheaper model)
            messages=[
                {"role": "system", "content": systemPrompt},
                {"role": "user", "content": prompt}
            ],
            temperature=0.7,
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error occurred: {e}")
        return None
    
def get_reasoning_completion(prompt):
    try:
        response = client.chat.completions.create(
            model="o1-mini",  # Using O1 reasoning model
            messages=[
                {"role": "user", "content": systemPrompt + prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error occurred: {e}")
        return None

# Create a list to store responses
responses = []

# Iterate through the sampled problems
for idx, row in sampled_df.iterrows():
    print(f"Processing problem {idx + 1}/10...")
    
    # Create the prompt
    prompt = f"Please solve this problem: {row['Problem']}"
    
    # Get completion and add delay to respect rate limits
    # response = get_completion(prompt)
    response = get_reasoning_completion(prompt)
    responses.append(response)
    time.sleep(1)  # Add a delay between requests to respect rate limits

# Add responses to the dataframe
sampled_df['model_response'] = responses

# Display the results
display(sampled_df[['Problem', 'model_response']])
# Out:
# Processing problem 1395/10...
# Processing problem 744/10...
# Processing problem 1607/10...
# Processing problem 50/10...
# Processing problem 189/10...
# Processing problem 483/10...
# Processing problem 893/10...
# Processing problem 614/10...
# Processing problem 1629/10...
# Processing problem 1348/10...
#                                                 Problem  \
# 1394  You are on a road trip and the car breaks down...
# 743   A baseball has been thrown over a towering fen...
# 1606  Your water purification tablets fell into a de...
# 49    Your puppy chewed up a pillow, and now there a...
# 188    You have to hang a wall decoration, but you c...
# 482   You want to make a sun dial to judge time, but...
# 892   You are exploring through a zoo, and there's a...
# 613   During a beach cleanup, you come across a heav...
# 1628  A crack has formed on your car's radiator and ...
# 1347  You need to inflate a flat pool float but have...
#
#                                          model_response
# 1394  It is not possible to fix the engine with the ...
# 743   **Step 1:** Tie one jump rope securely to the ...
# 1606  **Step 1:** Use the Swiss army knife’s hook to...
# 49    **Step1:** Use the **fan** to blow and gather ...
# 188   **Step 1:** Lay multiple deck of cards side by...
# 482   **Step1:** Use the paper plate as the base of ...
# 892   **Step1:** Attach the basket of vegetables sec...
# 613   It is not possible to safely move the heavy lo...
# 1628  **Step1:** Clean the radiator crack area using...
# 1347  **Step1:** Attach the straw securely to the po...

# %%
display(sampled_df[['Problem', 'model_response','Solvable?','Solution']])
# Out:
#                                                 Problem  \
# 1394  You are on a road trip and the car breaks down...
# 743   A baseball has been thrown over a towering fen...
# 1606  Your water purification tablets fell into a de...
# 49    Your puppy chewed up a pillow, and now there a...
# 188    You have to hang a wall decoration, but you c...
# 482   You want to make a sun dial to judge time, but...
# 892   You are exploring through a zoo, and there's a...
# 613   During a beach cleanup, you come across a heav...
# 1628  A crack has formed on your car's radiator and ...
# 1347  You need to inflate a flat pool float but have...
#
#                                          model_response Solvable?  \
# 1394  It is not possible to fix the engine with the ...        No
# 743   **Step 1:** Tie one jump rope securely to the ...       Yes
# 1606  **Step 1:** Use the Swiss army knife’s hook to...        No
# 49    **Step1:** Use the **fan** to blow and gather ...       Yes
# 188   **Step 1:** Lay multiple deck of cards side by...       Yes
# 482   **Step1:** Use the paper plate as the base of ...       Yes
# 892   **Step1:** Attach the basket of vegetables sec...       Yes
# 613   It is not possible to safely move the heavy lo...       Yes
# 1628  **Step1:** Clean the radiator crack area using...        No
# 1347  **Step1:** Attach the straw securely to the po...        No
#
#                                                Solution
# 1394  It is not possible to fix a car engine with ju...
# 743   Step1: Tie the two jump ropes together to leng...
# 1606  Step1: Use the pot to collect rainwater or sta...
# 49    Step1: Use the broken broom to gather the feat...
# 188   Step1: Align the deck of cards along the wall ...
# 482   Step1: Use the hand mirror as the sundial base...
# 892   Step1: Fill the metallic bucket with fresh veg...
# 613   Step1: Use the volleyball as a roller under th...
# 1628  Step1: Clean the cracked area on the radiator ...
# 1347  Step1: Take the trash bag and secure it around...

# %%
# Save to excel file
sampled_df.to_excel('../../data/MacGyver/o1_response.xlsx', index=False)

# %% [markdown]
# ## Step 3 - Summary and Analysis
#
# - The calls are made and evaluated and we can see that there is often disagreement between what is solvable whether the solution is feasible or not.
# - Many of the results that are generated are also hard to evaluate - especially because there aren't defined answers and one could also say that the LLM came up with a creative solution.
# - In the original paper, the authors samples a set of 323 questions and then had human annotators go through the answers by each LLM and say whether the answer generated by LLM and human are correct or not.
# - In fact, they went one step further by also classifying the answers in five categories
#
# So now the open question is, how can we judge the quality and accuracy of the generated response from the reasoning models to determine if the reasoning LLMs generate better answers.

# %% [markdown]
# Possible approach: since we do not have the capacity to hire human annotators, our goal is to do this on a subset of the data. Here's what we are going to do:
#
# 1. Pick a set of 10 questions that look appealing to you. We will apply the following condition:
#     a. Puzzles are interesting and could be appealing when presented to potential readers
#     b. Puzzles are marked solvable in the original dataset - no point worrying about puzzles that can't be solved
#     c. Look for Puzzles that already have human solutions in the other file -> this is good for comparison with LLM solutions
# 2. For these 10 questions: ask GPT-4o, o3 and DeepSeek-R1 for responses. Start with 1 response and consider additional calls if required.
# 3. For each of the 10 questions we analyze the response to each question and determine if it's interesting:
#     a. Marked the answer as solvable -> this will give you a comparison between LLMs
#     b. How creative is the LLM solution compared to the Human solution -> this tells us if there is creativity in the LLM
#     c. How valid/feasible is the LLM solution -> this tells us whether it actually makes sense

# %% [markdown]
# ### Pick 10 questions
#
# I used Cline to generate a simple front-end app to read in questions from the excel file and present it to me with two buttons - Interesting and Not Interesting. This was then recorded as an additional column in the excel sheet.
# I filtered the Excel to contain Interesting and Solvable problems and ended up with 22 problems.
# Of these, I pick ten which are interesting with a preference for those that also have solutions in the other excel sheet called - additional_human_solutions.
# Selected problemIDs are:
#
# 359
# 1155
# 937
# 1591
# 541
# 443
# 480
# 798
# 669
# 1366

# %%
# Create a dataset containing only the selected questions

# Read the Excel file
df = pd.read_excel('../../data/MacGyver/problem_solution_pair.xlsx')

# List of selected problem IDs
selected_ids = [359, 1155, 937, 1591, 541, 443, 480, 798, 669, 1366]

# Filter dataframe to only include selected problems
selected_problems_df = df[df['ID'].isin(selected_ids)]

# Display the filtered dataset
selected_problems_df
# Out:
#         ID                                            Problem Solvable?  \
# 0      541  You spilled red wine on the hotel carpet and w...       Yes
# 24     443   You need to crush some ice for making cocktai...       Yes
# 50     359  Your cat has managed to get itself onto the to...       Yes
# 96     480   Your sleeping bag zipper is broken, and you'r...       Yes
# 223    798  You need to create a safe area in pool for kid...       Yes
# 306    669  You need to amplify the audio coming from your...       Yes
# 579   1155  You need to chop a lot of hard and large veget...       Yes
# 608   1366  While exploring a remote jungle, you accidenta...       Yes
# 766    937  You need to grind whole black peppercorns for ...       Yes
# 1129  1591  You want to train your flowering vine to grow ...       Yes
#
#      Unconventional?                                           Solution  \
# 0     unconventional  Step1: Open the bottle of mineral water with t...
# 24    unconventional  Step1: Put on the rubber gloves to prevent you...
# 50    unconventional  Step1: Set up the step stool near the bookcase...
# 96    unconventional  Step1: Lay your sleeping bag on the flat groun...
# 223   unconventional  Step1: Use floating rings by stringing pool no...
# 306   unconventional  Step1: Trim one end of the paper towel tube to...
# 579   unconventional  1. Use the peeler to remove the skin of the ve...
# 608     conventional  Step 1: Use the sturdy vine as a splint, placi...
# 766   unconventional  Step1: Place the peppercorns in the glass jar....
# 1129  unconventional  Step1: Wear gardening gloves for protection. <...
#
#             Label  IsInteresting
# 0     inefficient            1.0
# 24    inefficient            1.0
# 50     infeasible            1.0
# 96      efficient            1.0
# 223    infeasible            1.0
# 306   inefficient            1.0
# 579    infeasible            1.0
# 608   inefficient            1.0
# 766    infeasible            1.0
# 1129   infeasible            1.0

# %%
## Call GPT-4o to get the basic set of answers
import os
from openai import OpenAI
import time

# Initialize the OpenAI client
client = OpenAI()  # Make sure OPENAI_API_KEY is set in your environment variables
systemPrompt = "Give a valid (feasible and efficient) solution very concisely. Use step1, step2, etc, and mention the tools to achieve each step. Use as few steps as possible and the answer should ideally be less than 100 words. When there is not a feasible solution given the constraint and provided tools, just say that it is not possible and give a very short justification."

def get_completion(prompt):
    try:
        response = client.chat.completions.create(
            model="gpt-4o",  # Using GPT-4o (cheaper model)
            messages=[
                {"role": "system", "content": systemPrompt},
                {"role": "user", "content": prompt}
            ],
            temperature=0.7,
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error occurred: {e}")
        return None
    
# Create a list to store responses
responses = []

# Iterate through each problem in the dataframe
for _, row in selected_problems_df.iterrows():
    # Get the problem text
    problem = row['Problem']
    
    # Add a delay between API calls to avoid rate limiting
    time.sleep(1)
    
    # Get completion for this problem
    response = get_completion(problem)
    
    # Store the response
    responses.append(response)

# Add responses as a new column to the dataframe
selected_problems_df['gpt4o_response'] = responses
# Out:
# /var/folders/c7/vsymt57x6ml510pt0z0929z40000gp/T/ipykernel_18157/357181195.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_problems_df['gpt4o_response'] = responses

# %%
# Display the problems and their responses
selected_problems_df[['Problem', 'gpt4o_response']]
# Out:
#                                                 Problem  \
# 0     You spilled red wine on the hotel carpet and w...
# 24     You need to crush some ice for making cocktai...
# 50    Your cat has managed to get itself onto the to...
# 96     Your sleeping bag zipper is broken, and you'r...
# 223   You need to create a safe area in pool for kid...
# 306   You need to amplify the audio coming from your...
# 579   You need to chop a lot of hard and large veget...
# 608   While exploring a remote jungle, you accidenta...
# 766   You need to grind whole black peppercorns for ...
# 1129  You want to train your flowering vine to grow ...
#
#                                          gpt4o_response
# 0     Step 1: Blot the stain with the white bath tow...
# 24    1. **Fill Ziploc Bag**: Fill the snack-size Zi...
# 50    Step 1: Place the step stool next to the bookc...
# 96    Step 1: Use the duct tape to seal the zipper a...
# 223   Step 1: Form a boundary by threading the pool ...
# 306   Step 1: Use the pen to trace the outline of th...
# 579   It is not possible to efficiently chop hard an...
# 608   1. **Align Leaves**: Place the large leaves on...
# 766   1. **Smash with Jar:** Place the peppercorns i...
# 1129  1. **Prepare Materials**: Remove the fabric fr...

# %% [markdown]
# GPT-4o findings:
# - It declared that two of the questions are not solvable when ground truth says that it is. In the latest run, it found that only one problem is not solvable - so it changes between runs as well - important to keep in mind.
# - Additional observations after manual review

# %%
## Call o1-mini to get the first set of reasoning model answers

def get_reasoning_completion(prompt):
    try:
        response = client.chat.completions.create(
            model="o1-mini",  # Using O1 reasoning model
            messages=[
                {"role": "user", "content": systemPrompt + prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error occurred: {e}")
        return None
    
# Create a list to store responses
responses = []

# Iterate through each problem in the dataframe
total_problems = len(selected_problems_df)
for idx, (_, row) in enumerate(selected_problems_df.iterrows(), 1):
    # Get the problem text
    problem = row['Problem']
    
    print(f"Processing problem {idx}/{total_problems}")
    print(f"Problem text: {problem[:100]}...")  # Print first 100 chars
    
    # Add a delay between API calls to avoid rate limiting
    time.sleep(1)
    
    # Get completion for this problem
    response = get_reasoning_completion(problem)
    
    if response:
        print("Successfully got response")
    else:
        print("Failed to get response")
        
    # Store the response
    responses.append(response)
    print("-" * 80)

# Add responses as a new column to the dataframe
selected_problems_df['o1mini_response'] = responses
# Out:
# Processing problem 1/10
# Problem text: You spilled red wine on the hotel carpet and want to clean it up before the housekeeping staff repor...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 2/10
# Problem text:  You need to crush some ice for making cocktails, but you don't have an ice crusher or blender. The ...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 3/10
# Problem text: Your cat has managed to get itself onto the top shelf of a high bookcase, and you need to get it saf...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 4/10
# Problem text:  Your sleeping bag zipper is broken, and you're unable to close it for warmth during a cold night of...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 5/10
# Problem text: You need to create a safe area in pool for kids to play but you don't have a pool divider. Tools ava...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 6/10
# Problem text: You need to amplify the audio coming from your smartphone's speakers to share a recording with your ...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 7/10
# Problem text: You need to chop a lot of hard and large vegetables but your knife is blunt. You have an egg whisk, ...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 8/10
# Problem text: While exploring a remote jungle, you accidentally injure your leg, and you need to immobilize it bef...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 9/10
# Problem text: You need to grind whole black peppercorns for a recipe, but your pepper mill is broken. Tools availa...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 10/10
# Problem text: You want to train your flowering vine to grow around a particular path, but don't have a trellis. Yo...
# Successfully got response
# --------------------------------------------------------------------------------
# /var/folders/c7/vsymt57x6ml510pt0z0929z40000gp/T/ipykernel_18157/2320089794.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_problems_df['o1mini_response'] = responses

# %%
# Display the problems and their responses
selected_problems_df[['Problem', 'gpt4o_response', 'o1mini_response']]
# Out:
#                                                 Problem  \
# 0     You spilled red wine on the hotel carpet and w...
# 24     You need to crush some ice for making cocktai...
# 50    Your cat has managed to get itself onto the to...
# 96     Your sleeping bag zipper is broken, and you'r...
# 223   You need to create a safe area in pool for kid...
# 306   You need to amplify the audio coming from your...
# 579   You need to chop a lot of hard and large veget...
# 608   While exploring a remote jungle, you accidenta...
# 766   You need to grind whole black peppercorns for ...
# 1129  You want to train your flowering vine to grow ...
#
#                                          gpt4o_response  \
# 0     Step 1: Blot the stain with the white bath tow...
# 24    1. **Fill Ziploc Bag**: Fill the snack-size Zi...
# 50    Step 1: Place the step stool next to the bookc...
# 96    Step 1: Use the duct tape to seal the zipper a...
# 223   Step 1: Form a boundary by threading the pool ...
# 306   Step 1: Use the pen to trace the outline of th...
# 579   It is not possible to efficiently chop hard an...
# 608   1. **Align Leaves**: Place the large leaves on...
# 766   1. **Smash with Jar:** Place the peppercorns i...
# 1129  1. **Prepare Materials**: Remove the fabric fr...
#
#                                         o1mini_response
# 0     **Step1:** Use the bottle opener to open the m...
# 24    **Step1:** Place ice into the small Ziploc bag...
# 50    **Step1:** Position the step stool securely be...
# 96    **Step1:** Pull the zipper closed as much as p...
# 223   **Step 1:** Lay pool noodles side by side arou...
# 306   **Step 1:** Use the cardboard box as a speaker...
# 579   **Step1:** Use the rolling pin to flatten the ...
# 608   **Step 1:** Lay large leaves alongside both si...
# 766   **Step1:** Place peppercorns in the paper bag....
# 1129  **Step1:** Unfold the broken umbrella’s metal ...

# %% [markdown]
# o1-mini findings:
# - The number of unsolved problems has reduced to one (GPT-4o had two unsolved). In the latest run, all problems were solved by O1-mini - again a change from one run to the next.
# - Additional observations after manual review

# %%
# Call o3-mini to get a supposedly better reasoning model
# Make use of OpenRouter to do this call as I do not have direct access to the o3-mini API

from openai import OpenAI

openRouterclient = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.environ.get('OPENROUTER_API_KEY'),
)

def get_reasoning_completion(prompt):
    try:
        response = openRouterclient.chat.completions.create(
            model="openai/o3-mini",  # Using O3 reasoning model
            messages=[
                {"role": "user", "content": systemPrompt + prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error occurred: {e}")
        return None
    
# Create a list to store responses
responses = []

# Iterate through each problem in the dataframe
total_problems = len(selected_problems_df)
for idx, (_, row) in enumerate(selected_problems_df.iterrows(), 1):
    # Get the problem text
    problem = row['Problem']
    
    print(f"Processing problem {idx}/{total_problems}")
    print(f"Problem text: {problem[:100]}...")  # Print first 100 chars
    
    # Add a delay between API calls to avoid rate limiting
    time.sleep(1)
    
    # Get completion for this problem
    response = get_reasoning_completion(problem)
    
    if response:
        print("Successfully got response")
    else:
        print("Failed to get response")
        
    # Store the response
    responses.append(response)
    print("-" * 80)

# Add responses as a new column to the dataframe
selected_problems_df['o3mini_response'] = responses
# Out:
# Processing problem 1/10
# Problem text: You spilled red wine on the hotel carpet and want to clean it up before the housekeeping staff repor...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 2/10
# Problem text:  You need to crush some ice for making cocktails, but you don't have an ice crusher or blender. The ...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 3/10
# Problem text: Your cat has managed to get itself onto the top shelf of a high bookcase, and you need to get it saf...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 4/10
# Problem text:  Your sleeping bag zipper is broken, and you're unable to close it for warmth during a cold night of...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 5/10
# Problem text: You need to create a safe area in pool for kids to play but you don't have a pool divider. Tools ava...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 6/10
# Problem text: You need to amplify the audio coming from your smartphone's speakers to share a recording with your ...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 7/10
# Problem text: You need to chop a lot of hard and large vegetables but your knife is blunt. You have an egg whisk, ...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 8/10
# Problem text: While exploring a remote jungle, you accidentally injure your leg, and you need to immobilize it bef...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 9/10
# Problem text: You need to grind whole black peppercorns for a recipe, but your pepper mill is broken. Tools availa...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 10/10
# Problem text: You want to train your flowering vine to grow around a particular path, but don't have a trellis. Yo...
# Successfully got response
# --------------------------------------------------------------------------------
# /var/folders/c7/vsymt57x6ml510pt0z0929z40000gp/T/ipykernel_18157/2021697395.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_problems_df['o3mini_response'] = responses

# %%
# Display the problems and their responses
selected_problems_df[['Problem', 'gpt4o_response', 'o1mini_response', 'o3mini_response']]
# Out:
#                                                 Problem  \
# 0     You spilled red wine on the hotel carpet and w...
# 24     You need to crush some ice for making cocktai...
# 50    Your cat has managed to get itself onto the to...
# 96     Your sleeping bag zipper is broken, and you'r...
# 223   You need to create a safe area in pool for kid...
# 306   You need to amplify the audio coming from your...
# 579   You need to chop a lot of hard and large veget...
# 608   While exploring a remote jungle, you accidenta...
# 766   You need to grind whole black peppercorns for ...
# 1129  You want to train your flowering vine to grow ...
#
#                                          gpt4o_response  \
# 0     Step 1: Blot the stain with the white bath tow...
# 24    1. **Fill Ziploc Bag**: Fill the snack-size Zi...
# 50    Step 1: Place the step stool next to the bookc...
# 96    Step 1: Use the duct tape to seal the zipper a...
# 223   Step 1: Form a boundary by threading the pool ...
# 306   Step 1: Use the pen to trace the outline of th...
# 579   It is not possible to efficiently chop hard an...
# 608   1. **Align Leaves**: Place the large leaves on...
# 766   1. **Smash with Jar:** Place the peppercorns i...
# 1129  1. **Prepare Materials**: Remove the fabric fr...
#
#                                         o1mini_response  \
# 0     **Step1:** Use the bottle opener to open the m...
# 24    **Step1:** Place ice into the small Ziploc bag...
# 50    **Step1:** Position the step stool securely be...
# 96    **Step1:** Pull the zipper closed as much as p...
# 223   **Step 1:** Lay pool noodles side by side arou...
# 306   **Step 1:** Use the cardboard box as a speaker...
# 579   **Step1:** Use the rolling pin to flatten the ...
# 608   **Step 1:** Lay large leaves alongside both si...
# 766   **Step1:** Place peppercorns in the paper bag....
# 1129  **Step1:** Unfold the broken umbrella’s metal ...
#
#                                         o3mini_response
# 0     Step 1: Use the bottle opener to pry open the ...
# 24    Step 1: Place several ice cubes into a snack‐s...
# 50    Step 1: Place the soft blanket and pillow on t...
# 96    Step 1: Close the zipper as much as possible. ...
# 223   Step 1: Thread pool noodles through the inner ...
# 306   Step 1: Cut a wide opening in the cardbox to a...
# 579   Step 1: Place the vegetables on a firm surface...
# 608   Step 1 (Cushioning): Wrap large leaves in the ...
# 766   Step 1: Place the peppercorns inside the paper...
# 1129  Step 1: Clean the broken umbrella’s metal skel...

# %% [markdown]
# o3-mini findings:
# - As expected, it solves all the problems while o1-mini had missed out on one of them
# - Additional observations after manual inspection

# %%
# Call DeepSeek to get a supposedly cheaper reasoning model
# Make use of OpenRouter to do this call as I do not have direct access to the DeepSeek API

from openai import OpenAI

openRouterclient = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.environ.get('OPENROUTER_API_KEY'),
)

def get_reasoning_completion(prompt):
    try:
        response = openRouterclient.chat.completions.create(
            model="deepseek/deepseek-r1",  # Using DeepSeek reasoning model
            messages=[
                {"role": "user", "content": systemPrompt + prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        print(f"Error occurred: {e}")
        return None
    
# Create a list to store responses
responses = []

# Iterate through each problem in the dataframe
total_problems = len(selected_problems_df)
for idx, (_, row) in enumerate(selected_problems_df.iterrows(), 1):
    # Get the problem text
    problem = row['Problem']
    
    print(f"Processing problem {idx}/{total_problems}")
    print(f"Problem text: {problem[:100]}...")  # Print first 100 chars
    
    # Add a delay between API calls to avoid rate limiting
    time.sleep(1)
    
    # Get completion for this problem
    response = get_reasoning_completion(problem)
    
    if response:
        print("Successfully got response")
    else:
        print("Failed to get response")
        
    # Store the response
    responses.append(response)
    print("-" * 80)

# Add responses as a new column to the dataframe
selected_problems_df['deepseek_response'] = responses
# Out:
# Processing problem 1/10
# Problem text: You spilled red wine on the hotel carpet and want to clean it up before the housekeeping staff repor...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 2/10
# Problem text:  You need to crush some ice for making cocktails, but you don't have an ice crusher or blender. The ...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 3/10
# Problem text: Your cat has managed to get itself onto the top shelf of a high bookcase, and you need to get it saf...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 4/10
# Problem text:  Your sleeping bag zipper is broken, and you're unable to close it for warmth during a cold night of...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 5/10
# Problem text: You need to create a safe area in pool for kids to play but you don't have a pool divider. Tools ava...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 6/10
# Problem text: You need to amplify the audio coming from your smartphone's speakers to share a recording with your ...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 7/10
# Problem text: You need to chop a lot of hard and large vegetables but your knife is blunt. You have an egg whisk, ...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 8/10
# Problem text: While exploring a remote jungle, you accidentally injure your leg, and you need to immobilize it bef...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 9/10
# Problem text: You need to grind whole black peppercorns for a recipe, but your pepper mill is broken. Tools availa...
# Successfully got response
# --------------------------------------------------------------------------------
# Processing problem 10/10
# Problem text: You want to train your flowering vine to grow around a particular path, but don't have a trellis. Yo...
# Successfully got response
# --------------------------------------------------------------------------------
# /var/folders/c7/vsymt57x6ml510pt0z0929z40000gp/T/ipykernel_18157/1612522772.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_problems_df['deepseek_response'] = responses

# %%
# Display the problems and their responses
selected_problems_df[['Problem', 'gpt4o_response', 'o1mini_response', 'o3mini_response', 'deepseek_response']]
# Out:
#                                                 Problem  \
# 0     You spilled red wine on the hotel carpet and w...
# 24     You need to crush some ice for making cocktai...
# 50    Your cat has managed to get itself onto the to...
# 96     Your sleeping bag zipper is broken, and you'r...
# 223   You need to create a safe area in pool for kid...
# 306   You need to amplify the audio coming from your...
# 579   You need to chop a lot of hard and large veget...
# 608   While exploring a remote jungle, you accidenta...
# 766   You need to grind whole black peppercorns for ...
# 1129  You want to train your flowering vine to grow ...
#
#                                          gpt4o_response  \
# 0     Step 1: Blot the stain with the white bath tow...
# 24    1. **Fill Ziploc Bag**: Fill the snack-size Zi...
# 50    Step 1: Place the step stool next to the bookc...
# 96    Step 1: Use the duct tape to seal the zipper a...
# 223   Step 1: Form a boundary by threading the pool ...
# 306   Step 1: Use the pen to trace the outline of th...
# 579   It is not possible to efficiently chop hard an...
# 608   1. **Align Leaves**: Place the large leaves on...
# 766   1. **Smash with Jar:** Place the peppercorns i...
# 1129  1. **Prepare Materials**: Remove the fabric fr...
#
#                                         o1mini_response  \
# 0     **Step1:** Use the bottle opener to open the m...
# 24    **Step1:** Place ice into the small Ziploc bag...
# 50    **Step1:** Position the step stool securely be...
# 96    **Step1:** Pull the zipper closed as much as p...
# 223   **Step 1:** Lay pool noodles side by side arou...
# 306   **Step 1:** Use the cardboard box as a speaker...
# 579   **Step1:** Use the rolling pin to flatten the ...
# 608   **Step 1:** Lay large leaves alongside both si...
# 766   **Step1:** Place peppercorns in the paper bag....
# 1129  **Step1:** Unfold the broken umbrella’s metal ...
#
#                                         o3mini_response  \
# 0     Step 1: Use the bottle opener to pry open the ...
# 24    Step 1: Place several ice cubes into a snack‐s...
# 50    Step 1: Place the soft blanket and pillow on t...
# 96    Step 1: Close the zipper as much as possible. ...
# 223   Step 1: Thread pool noodles through the inner ...
# 306   Step 1: Cut a wide opening in the cardbox to a...
# 579   Step 1: Place the vegetables on a firm surface...
# 608   Step 1 (Cushioning): Wrap large leaves in the ...
# 766   Step 1: Place the peppercorns inside the paper...
# 1129  Step 1: Clean the broken umbrella’s metal skel...
#
#                                       deepseek_response
# 0     **Step1:** Use the bottle opener to unseal the...
# 24    **Step1:** Fill the snack-size Ziploc bag with...
# 50    **Step1:** Place the pillow, soft blanket, and...
# 96    **Step1:** Align the zipper edges and use clot...
# 223   **Step1:** Interlock pool noodles by threading...
# 306   **Step1:** Place the smartphone inside the car...
# 579   **Step1:** Use the **peeler** to remove skins....
# 608   **Step1:** Flatten the water bottle to form a ...
# 766   **Step1:** Place peppercorns on the **cheese g...
# 1129  **Step1:** Repurpose the umbrella's metal skel...

# %%
# Save the dataframe to Excel
selected_problems_df.to_excel('../../data/MacGyver/reasoning_model_responses.xlsx', index=False)

# %%
# Display the first row with full text
pd.set_option('display.max_colwidth', None)

first_row = selected_problems_df[['Problem', 'gpt4o_response', 'o1mini_response', 'o3mini_response', 'deepseek_response']].iloc[0]

print("\nProblem:")
print("-" * 80)
print(first_row['Problem'])
print("\nGPT-4 Response:")
print("-" * 80) 
print(first_row['gpt4o_response'])
print("\nOlympus-1 Response:")
print("-" * 80)
print(first_row['o1mini_response'])
print("\nOlympus-3 Response:") 
print("-" * 80)
print(first_row['o3mini_response'])
print("\nDeepseek Response:")
print("-" * 80)
print(first_row['deepseek_response'])

pd.reset_option('display.max_colwidth')
# Out:
# Problem:
# --------------------------------------------------------------------------------
# You spilled red wine on the hotel carpet and want to clean it up before the housekeeping staff reports this. Tools available: a bottle opener, a plastic cup, a toothbrush, a bottle of mineral water that is sealed shut, a pack of sugar, a white bath towel, a bar of soap, a hair dryer. How do you clean up the wine stain using only these items?
#
# GPT-4 Response:
# --------------------------------------------------------------------------------
# Step 1: Blot the stain with the white bath towel to absorb as much wine as possible.
# Step 2: Open the sealed bottle of mineral water and pour a small amount over the stain to dilute it.
# Step 3: Use the toothbrush to gently scrub the diluted stain with the water.
# Step 4: Rub the bar of soap on the toothbrush, then scrub the stain further to help lift it.
# Step 5: Blot again with the towel to remove excess moisture.
# Step 6: Use the hair dryer on a low setting to dry the area.
#
# Olympus-1 Response:
# --------------------------------------------------------------------------------
# **Step1:** Use the bottle opener to open the mineral water bottle.
# **Step2:** Pour mineral water from the open bottle into the plastic cup.
# **Step3:** Blot the wine stain with the white bath towel to absorb excess wine.
# **Step4:** Sprinkle sugar over the stain to吸吸 remaining wine, let sit for 5 minutes.
# **Step5:** Use the toothbrush and bar of soap to gently scrub the area.
# **Step6:** Rinse with mineral water from the cup.
# **Step7:** Blot dry with the towel and use the hair dryer to speed up drying.
#
# Olympus-3 Response:
# --------------------------------------------------------------------------------
# Step 1: Use the bottle opener to pry open the sealed mineral water bottle.
# Step 2: Blot the excess wine with the white bath towel.
# Step 3: With the plastic cup, pour a small amount of mineral water over the stain.
# Step 4: Mix a little water with the bar soap and scrub the area with the toothbrush.
# Step 5: Sprinkle sugar over the treated spot to absorb remaining moisture, then dry it thoroughly using the hair dryer.
#
# Deepseek Response:
# --------------------------------------------------------------------------------
# **Step1:** Use the bottle opener to unseal the mineral water.
# **Step2:** Pour water (using the cup) on the stain to dilute it; blot repeatedly with the towel.
# **Step3:** Scrub gently with the toothbrush and soap to lift the stain, then rinse with water.
# **Step4:** Blot again with the dry part of the towel.
# **Step5:** Use the hair dryer (cool setting) to dry the area, preventing residue.
#
# *Feasible*: Combines dilution, cleaning, and drying with available tools.

# %% [markdown]
# ## Analysis of results
#
# I'm trying to capture my thoughts as I have analyzed the 10 problems and the solutions provided by multiple LLMs:
#
# 1. In many cases, the general approach provided by the human solution and all the LLMs are very similar - they tend to agree with each other. This is true for Problem ID 359: Cat on a high library shelf, Problem ID 669: Amplifying phone speaker by using cardboard box as reasonating chamber, Problem ID 443: crushing ice.
# 2. In some cases, the tools used by the LLM are not used by the human solution. Problem 1366: creating a splint on a broke leg - all the LLMs tend to use the bottle as the splint whereas the human solution doesn't use the bottle at all. Surprisingly, GPT4o acts similar to human solution and does not consider the bottle. Problem 937: crushing pepper corns the human and all OpenAI solutions use the fork to crush the pepper corns. But the Deepseek solution asks to use the glass jar to gring the corns against the greater which seemed more feasible to me.
# 3. There was also Problem ID 1155: chopping vegetables where gpt4o could not come up with a solution whereas the reasoning LLMs all came up with reasonable solutions similar to the human solution.
# 4. Problem ID 480: sleeping bag zipper - this is where I thought the human solution was much better thought out and complete rather than any of the LLM solution. Clearly outperforms LLMs.
